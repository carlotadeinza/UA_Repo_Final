# %% [markdown]
# # **Assignment 1** - 200017209
# # GG4257 - Urban Analytics: A Toolkit for Sustainable Urban Development
# # Lab Workbook No 1: Python Basics

# %% [markdown]
# ### **Carlota de Inza** - 200017209
# #### carlotadeinza - https://github.com/carlotadeinza/UARepo/new/main#:~:text=Breadcrumbs-,UARepo,-/
#
# ###### Websites of interest:
#   1. https://www.trccompanies.com/
#   2. https://www.aecogen.com/
#   3. https://investingreen.energy/

# %% [markdown]
# # Challenge 1:
#  Create a table with required columns and rows to represent the type of roads in the UK. The table should include headers and hiperlinks.

# %% [markdown]
# # Types of Roads in the UK
#
# | Type of Roads | Insights Into their Natures |
# |----------|----------|
# |A-Roads    | [What are national highways](https://nationalhighways.co.uk/our-roads/history-of-modern-a-roads/#:~:text=The%20British%20road%20numbering%20system&text=To%20make%20sense%20of%20the,became%20classified%20as%20A%2Droads.) |
# |B and C-Roads| [What are the networks between major highways](https://www.eastriding.gov.uk/environment/roads-streets-traffic-and-parking/roads-pavements-and-traffic/classification-of-roads/)    |
# | Motorways   | [What are high speed roads](https://www.ice.org.uk/what-is-civil-engineering/what-do-civil-engineers-do/uk-motorways)     |
# | Sealed & Unsealed Roads     | [What differentiates sealed and unsealed roads](https://assets.publishing.service.gov.uk/media/57a08c3a40f0b649740010a0/C21-TRN-33-SurfacingOptions.pdf)   |

# %% [markdown]
# # Challenge 2:
#
# In the following cell, create the code to calculate the average of three numbers and print the result. There is no need for functions. Comment your code and the process.

# %%
# Declaring three variables (three numbers) with vaues 35, 67 and 123.
num1 = 35
num2 = 67
num3 = 123

# Summing the stated variables/numbers in order to calculate their average to later on divide them by 3.
sum_result = num1 + num2 + num3
print(f"Sum: {sum_result}")

# dividing the 'sum_result' of all three variables by the number of variables (3)
average_result = sum_result / 3
print(f"Average of values: {average_result}")

# %% [markdown]
# # Challenge 3:
#
# Write a condition to check if a number is even.

# %%
# Define the function needed to check if a number is even with 'def' and 'return' number % 2 == 0
def is_even(number):
    return number % 2 == 0
    
# Test the function with number chosen: 7
number_to_check = 7
if is_even(number_to_check):
    print(f"{number_to_check} is even.")
else:
    print(f"{number_to_check} is odd.")

# %% [markdown]
# # Challenge 4:
#
# Write the python code  to find the factorial of a number using a loop. Thefactorial of a number (integer positive) is the sum of multiplication of all the integers smaller than that positive integer. For example, factorial of **5** is:
#
# 5 * 4 * 3 * 2 * 1 which equals to 120.
#
# How you can do that in a python script?, please try your best without using google.

# %%
# Calculating the factorial of 9 (sum of multiplication between numbers under 9) using a loop.
# Defining a function to calculate the factorial of the chosen number: 9
# Using a for / in loop indicating range to make it inclusive of all numbers up to 9.
# Factorial(n) is the defined function to calculate the factorial of number n.
# assigning *= to the a result is what operates the multiplication between a number and the next one, to drive the sum between them with (1, n + 1)
def factorial(n):
    result = 1
    for i in range(1, n + 1):
        result *= i
    return result

# Calculating the factorial of 9 by substituting n with 9 and naming it factorial_9 to allow the operation to be read when printing the result.
factorial_of_9 = factorial(9)
print("Factorial of 9:", factorial_of_9)

# %% [markdown]
# # Challenge 5:
#
# Help me to write the python code, I can use to provide the grades based on the marks according to the following table:
#
# | Mark   | Grade |
# |--------|-------|
# | 81-100 | 20    |
# | 61-80  | 15    |
# | 41-60  | 10    |
# | 20-40  | 5     |

# %%
# Providing grades based on the marks above using if-else statements, should be something like this
# Creating a variable names mark where users will be able to put in a number and get the respective grade.
# I use the int(input("Enter the mark")) Python expression that will allow a user to to do so.
# if statement will test a condition, in the case below any mark below the integer 20, 
# for which if true it will print "Your grade is below a 5." as signlaized in the table above.
mark = int(input("Enter the mark"))

# Check if the variable age is greater than 18.
if mark < 20:
    print("Your grade is below a 5.")
    
# Elif essentially reads else if (otherwise) to the previous statement, 
# which I will break down into ranges of 20 as indicated above, 
# indicating the first and last number of the 'mark' range and printing the grade it would equal to. 
# Use elif to check what grades marks between 20 and 40 are equal to.
elif 20 <= mark <= 40:
    print("Your grade is 5.")

# Use elif to check what grades marks between 41 and 60 are equal to.
elif 41 <= mark <= 60:
    print("Your grade is 10.")

# Use elif to check what grades marks between 61 and 80 are equal to.
elif 61 <= mark <= 80:
    print("Your grade is 15.")

# Use elif to check what grades marks between 81 and 100 are equal to.
elif 81 <= mark <= 100:
    print("Your grade is 20.")

# %% [markdown]
# # Challenge 6:
#
# * Write and use a function to convert Fahrenheit to Celsius. Use the input parameter to let the user enter a number in Fahrenheit and then get the correspondant value in Celsius
# * Go to https://www.w3schools.com/python/exercise.asp?filename=exercise_functions1 and complete the 6 excersices. Functions are a very important part of Python so we will use extra time to practice that.

# %%
# Defining the function that converts a fahrenheit degrees value into celsius using def
# and labelling it convert_fahrenheit_to_celsius while writting the function that converts fahrenheit to celsius. ((fahrenheit - 32) * 5 / 9)
# i'm also creating this operation under celsius 
def convert_fahrenheit_to_celsius(fahrenheit):
    celsius = (fahrenheit - 32) * 5 / 9
    return celsius

# Calling at the function to also provide a user to type in a number to be converted according to the below function int with input indicating to type the fahrenheit integers.
fahrenheit_input = int(input("Temperature in Fahrenheit:"))

# referring back to the defined function above convert_fahrenheit_to_celsius to apply it to the input under 'fahrenheit_input'
# labelling it celsius_output to be able to print it in the following step.
celsius_output = convert_fahrenheit_to_celsius(fahrenheit_input)

# Display the result using print and f to style the operation outcome and a print an answer that refers back to the labells stated in the previous steps 
print(f"{fahrenheit_input} Fahrenheit is equal to {celsius_output} Celsius.")

# %% [markdown]
# # Challenge 7:
#
# Calculate the mean and standard deviation of elements in a NumPy array. The outcome should have something like ``print(f"Mean: {mean_value}, Standard Deviation: {std_deviation}")``

# %%
# in order to perform calculations of elements in NumPy array I first import numpy library 
# and i assign it to alias np so that the following steps can perform the numerical operations.  
import numpy as np

# I create a 2D numpy array with np.array and label it arr to be able to refer back to it later.
# I spcify the list/grid of the values 14, 28 and 35 and 42, 57 and 61 using [] as well as , to separate them
arr = np.array([[14, 28, 35], [42, 57, 61]])

# I then use functions np.std and np.mean from the Numpy library 
# labelling them respectively to refer back to them when printing results. 
std_deviation = np.std(arr)
mean_value = np.mean(arr)
# I finally print the results from the functions above referring to their labells and using f to style the outcome of print.
print(f"Mean: {mean_value}, Standard Deviation: {std_deviation}")

# %% [markdown]
# # Challenge 8:
#
# You have the following dataframes 'sales_data' and 'movie_ratings'

# %%
# i first import the Pandas library and gives it the alias pd.
# This will allow me to create DataFrames as well as read data from CSV files within other functions the library provides.
import pandas as pd

# Sales Data is labelled to a dictionary containing sales data with columns Date, Region, Product, Quantity, and Revenue
sales_data_dict = {
    'Date': ['2022-01-01', '2022-01-02', '2022-01-03', '2022-01-04'],
    'Region': ['North', 'South', 'East', 'West'],
    'Product': ['A', 'B', 'A', 'C'],
    'Quantity': [15, 8, 12, 10],
    'Revenue': [1500, 1200, 1800, 900]
}
# creating a datafram out of the sales_data_dictionary
sales_data = pd.DataFrame(sales_data_dict)

# Movie Ratings is labelled to the creation of a dictionary containing movie ratings data with columns Title, Genre, Year, and Rating
movie_ratings_dict = {
    'Title': ['Movie1', 'Movie2', 'Movie3', 'Movie4'],
    'Genre': ['Action', 'Drama', 'Comedy', 'Thriller'],
    'Year': [2015, 2010, 2018, 2011],
    'Rating': [8.5, 7.8, 9.2, 8.0]
}
# creating a dataframe out of the movie_ratings_dictionary
movie_ratings = pd.DataFrame(movie_ratings_dict)
# Printing the sales data and movie rating DataFrames
print(sales_data)
print(movie_ratings)

# %% [markdown]
# * Display the first 5 rows of the DataFrame 'sales_data'
# * Use `loc` to filter and display rows where the "Quantity" is greater than 10 and the "Region" is "North".
# * Use `iloc` to display the values in the first row and the first three columns.
# * Calculate the total sales for each region and display the result.
#
# * Display the last 3 rows of the DataFrame 'movie_ratings'.
# * Calculate and display the average rating for each genre.

# %%
# indicate DataFrame 'sales_data' and head (as in the heading rows) indicating 5 to display only the first 5.
sales_data.head(5)

# %%
# filtering the sales_data usin loc to filter and display rows where the "Quantity" is greater than 10 and the "Region" is "North".
# loc access the data in a dataframe by label(s) by both column or row.
filtered_sales_data = sales_data.loc[(sales_data['Quantity'] > 10) & (sales_data['Region'] == 'North')]

# Displaying the filtered Dataframe according to the information in the loc indexer above
print(filtered_sales_data)

# %%
# Using 'iloc' to display the values in the first row and the first three columns.
# iloc (sales_data before .iloc to refer back to dataframe) can access rows and columns information from the dataframe by integer position(s).
# for this i specify 0, 0:3 to display the values in the first row and the first three columns ('0:3' selects rows from integer position 0 and columns from integer position 0 to 3)
salesdata_first_row_first_three_columns = sales_data.iloc[0, 0:3]

# Printing the Dataframe created 
print(salesdata_first_row_first_three_columns)

# %%
# Calculating the total sales (revenue-as written in the dataframe) for each region (region) and displaying the result.
# .groupby() method in Pandas groups rows of the sales_data DataFrame together based on two columns (revenue and region), 
# and then applies a sum function to each independently to calculate total sales by region
revenue_by_region = sales_data.groupby('Region')['Revenue'].sum()

# printing the result from the method and calculation above
print(revenue_by_region)

# %%
# Displaying the last 3 rows of the DataFrame 'movie_ratings'. similarly to before when 'head' was used, tail will be used to show the last values in the last rows.
movie_ratings.tail(3)

# %%
# Calculate and display the average rating (written as 'Rating' in the dataframe) for each genre (also written as 'Genre' in the dataframe).
# Using .mean() function to display the average and grouping genre and rating variables 
# as previously performed with .groupby() to rule out the other variables (title and year)
mean_rating_by_genre = movie_ratings.groupby('Genre')['Rating'].mean()

# printing the results
print(mean_rating_by_genre)

# %% [markdown]
# # Challenge 9:
#
# * Recreate the explore map, but now using one of the columns to create a choropleth map Check this link to get more information https://geopandas.org/en/stable/docs/reference/api/geopandas.GeoDataFrame.explore.html
#
# * Get the histogram of the raster you plot in the exercise. Here you can get an example of how to do it: https://rasterio.readthedocs.io/en/latest/topics/plotting.html

# %%
# importing necessary libraries to work with geospatial and raster data
# below is the GeoPandas library and gives it the alias gpd. It extends the capabilities of pandas dataframes to manipulate of geospatial data.
import geopandas as gpd
# Rasterio library reads and writes geospatial raster datasets.
# rasterio.plot import show imports the show function from the rasterio.plot and it is a function that allows to visualize raster datasets.
import rasterio
from rasterio.plot import show

# reading the shapefile 'Road_Safety_Accidents.shp' saved in my lab 1 folder directory in my laptop into a geodataframe
shapefile_path = '/Users/carlota/Documents/Documents - Carlota’s MacBook Air/UA Repo/Assigment 1 - 200017209/Lab 1/Road_Safety_Accidents.shp'
gdf = gpd.read_file(shapefile_path)

# checking the dataset gdf created from the shapefile imported.
gdf.head()

# %%
# exploring the contents of the shapefile for this, i have chosen .plot instead of .explore() 
# as my local libraries do not allow me to explore maps with .explore(). 
# to create a choropleth map i will specify which column i want to look at and 
#will choose number of accidents column labelled as NUMBER_OF_.
gdf.plot(column='NUMBER_OF_', legend=True)

# %% [markdown]
# ![image.png](attachment:3be4ca14-3738-4738-b4f2-74211ef105e0.png)

# %% [markdown]
# > The plot above represents number of accidents from the road safety dataset imported earlier in glasgow per area. It seems that most localities range between 2 to 6 number of accidents. There is only one visible 'yellow' spot which, as indicated by the legend, displays a number of over 10 accidents.

# %%
# Opening and displaying the raster image that i will use to plot a histogram and i labell it raster_path
raster_path = '/Users/carlota/Documents/Documents - Carlota’s MacBook Air/UA Repo/Assigment 1 - 200017209/Lab 1/elev.tif'
# with .open i open the raster file i just opened and with show() I display it
raster = rasterio.open(raster_path)
show(raster)

# %% [markdown]
# ![image.png](attachment:f9831ac7-326e-4955-871c-f33646e6acbb.png)

# %%
# Displaying a histogram of the raster plotted in the previus exercise.
# Referring back to 'raster' as was named previously, histogram is created by importing the single band raster data into show_hist
# Indicating a title of histogram as well as the type of histogram, in this case stepfield determining colour and edge shapes.

from rasterio.plot import show_hist
show_hist(
    raster, bins=50, lw=0.0, stacked=False, alpha=0.3,
    histtype='stepfilled', title="Histogram")

# %% [markdown]
# ![image.png](attachment:8a1f5913-4f6a-4f8c-b9e6-b4fbfdfe7721.png)

# %% [markdown]
# # Lab Workbook No 2: Data Manipulation and Working with Web Services

# %% [markdown]
# # Challenge No 1:
#
# 1. Using a Dictionary, create a dataframe (table), with at least 4 columns and more than 100 rows. How come you can create this among data from scratch without defining every single row of data?
# 2. Using the appropriate method, create a new DataFrame containing only the first 30 rows and the first 3 columns of the original DataFrame. Name this new DataFrame subset_df.
# 3. Using the appropriate method, filter the rows from the original dataframe where a numerical attribute(column) is greater than a particular numerical value, and find another categorical attribute that is equal to a specific string or text. Name this new DataFrame filtered_df.
# 4. Check this website https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.mean.html and apply the methods, mean, standard deviation, group_by to run fundamental statistical analysis of your created data frame.
# 5. Make sure you comment on your code and describe how you are manipulating the data.

# %%
# 1. Using a Dictionary, create a dataframe (table), with at least 4 columns and more than 100 rows. How come you can create this among data from scratch without defining every single row of data?
import numpy as np
import pandas as pd

# Creating a dictionary with at least 4 columns and more than 100 rows, for this i create 4 arrays to have at least 4 colums and randomize the variables x 125 times to have a minimum of 100 rows (in this case over 100 because i stated 125) (for this i use the randint() function to generate random integers)
# Using NumPy to generate arrays for each column with more than 100 elements saves up the effort from having to define row by row of data until reaching over 100.
names = np.random.choice(['Caroline', 'Carlota', 'Alexander', 'Peia', 'Ricardo', 'Nicholas'], 125)
ages = np.random.randint(15, 20, 125)
nationalities = np.random.choice(['Dutch', 'Spanish', 'Danish', 'Kenyan', 'French', 'Italian'], 125)
specialty = np.random.choice(['Science', 'Humanities', 'Arts', 'Science'], 125)
    
# Creating a dictionary with column names as keys and arrays as values according to the variables chosen above
data = {
    'Name': names,
    'Age': ages,
    'Nationality': nationalities,
    'Specialty': specialty
}

# Converting the dictionary to a DataFrame
df = pd.DataFrame(data)

# Displaying the first 5 rows of the DataFrame would use --> df.head(), but i will simply plot 'df' to show at the bottom that the dataframe consists of 120 rows and 4 columns
df

# %%
# 2. Using the appropriate method, I create a new DataFrame containing only the first 30 rows and the first 3 columns of the original DataFrame. I choose to name this new DataFrame subset_df.

# Df is the original DataFrame previously created

# Creating a new DataFrame called subset_df, which includes the first 30 rows and first 3 columns from df using iloc and the ':' colon is used to define a numeric vector between the two numbers
# I use 'iloc' because it is an integer-location based indexing, where rows and columns are specified by their integer indices and the data is selected based on its numerical position in the DataFrame.
# since the instruction name first 30 rows and 3 columns I can just specify by number
subset_df = df.iloc[:30, :3]

# Display the new DataFrame
print(subset_df)

# %%
# 3. Using the appropriate method, i filter the rows from the original dataframe where a numerical 
# attribute(column) is greater than a particular numerical value, and i find another categorical 
# attribute that is equal to a specific string or text. Naming this new DataFrame filtered_df.

# Df is the original DataFrame previously created

# Defining the numerical value threshold to be 18 (over age), since I am looking at an age range between 15 and 20 
numerical_threshold = 18

# Defining the specific string or text, since I am choosing a column of names, for 'specific_text' I have chosen Carlota, for example.
specific_text = 'Carlota'

# Filtering the rows based on the conditions and naming it filtered_df as per the instructions of the challenge
# loc is being used as the columns selected are going to be indicated by their names. Their names were spcified in the creation of the dictionary of the df DataFrame previously as 'Name' and 'Age'.

filtered_df = df.loc[(df['Age'] > numerical_threshold) & (df['Name'] == specific_text)]

# Displaying the new DataFrame with the filtered rows containing the 'name' = 'Carlota' and the 'Age' > '18'
print(filtered_df)

# %%
# 4. Check this website https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.mean.html and apply the methods, mean, standard deviation, group_by to run fundamental statistical analysis of your created data frame.
# Df is the DataFrame created
# Calculating the mean of the "Age" variable since it is the only numerical value
age_mean = df['Age'].mean()

# Print the mean age
print("Mean age:", age_mean)

# %%
# However, i would like to perform a more detailed statistical analysis
# for this I first define mean values and indicate i want it to print under 'Mean values' before i print it.
# Mean of numeric columns is done with df.mean() function also used previously (calling on df as the dataframe), which in this case it will only process the variable of'Age' as the only numerical column
mean_values = df.mean()
print("Mean values:")
print(mean_values)

# I then do the same for standard deviation, indicate it want it to print under 'Standard deviation values:'
# there is an "\n" before this title and it indicates the cell to escape a sequence and a newline character. This will be used in the following lines too to separate the outcomes in an ordered way.
# Standard deviation of numeric columns with df.std() also previously used (calling on df as the dataframe), which once again  will only process the variable of'Age' as it is the only numerical column
std_values = df.std()
print("\nStandard deviation values:")
print(std_values)

# Group by the variable 'Name' column (for example and as named in the dictionary created), using df.groupby() (calling on df as the dataframe), 
# and calculating the mean and standard deviation of 'Age' for each 'Name' group.
# I called this grouped stats and i .groupby (used earlier) to put together name and age and 
# aggregate (with .agg method) this grouped data to the mean and standard deviation functions.
# I finally print the results of the grouped stats and indicate i want it to print under 'Grouped statistics (mean and standard deviation of 'Age' for each gender):' for a clearer display.
grouped_stats = df.groupby('Name')['Age'].agg(['mean', 'std'])
print("\nGrouped statistics (mean and standard deviation of 'Age' for each gender):")
print(grouped_stats)

# %% [markdown]
# # Challenge No 2:
#
# **Part No 1:**
#
# 1. Using the same workflow previously described, now calculate the clustered areas for the GeoPandasDataFrame `gdf_bikes_end`
# 2. Make sure you don't have any NaN in your columns, add a CRS, clean up the unnecessary attributes, calculate the cluster values, and plot a map of 4 calculated clusters for the return locations.
#
# **Part No 2:**
#
# 1. Using the Glasglow Open Data API ( Transit) https://developer.glasgow.gov.uk/api-details#api=traffic&operation=traffic-sensor-locations fetch all the sensor locations in the city.
# 2. Map the sensor
# 3. Find the WorkingZones and Calculate/Map the areas with more and fewer sensors distributed in the city.
# 4. You will need:
#    * Get two separate Geopandas DataFrames, one for the traffic sensors and another one for the WorkingZones.
#    * Using `sJoin` ( Spatial Join) https://geopandas.org/en/stable/docs/reference/api/geopandas.sjoin.html
#    calculate the overlay of sensors and polygons.
#    * Using group_by https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.groupby.html to count the number of sensors per WorkingZone
#    * Make sure you add the counts into the WorkingZone polygons of Glasgow so you can create a map of Zones with more and fewer traffic sensors.
#    * Of course, you will need extra steps where you manipulate the data and extract what you need, for instance, clipping the Working Zones only for Glasgow.
# 5. Make sure you comment on your code and describe how you are manipulating the data.

# %%
#The following cells will contain the coding of the previous exercises to the challenge. 
# I maintained these here in order to have guidance and be able to refer back to the previous work done. 
# When Part 1 of the challenge begins it will be indicated.

# %%
# Previous work to challenge in order to perform work on data set for part number 1;
import requests
import pandas as pd
import geopandas as gpd

# Let's describe the url, it is usually easier to do it like this, so in the future, you can easily update the URL
url_bikes = "https://api.glasgow.gov.uk/mobility/v1/get_rentals?startDate=2022-05-01&endDate=2023-05-01"
# Making the query to the web server, using the Get method from the requests library 
response = requests.get(url_bikes)
response

# %%
#Now we get the response from the web server, we need to translate that into a format we can manipulate, like JSON.
data = response.json()
data
# careful here you will get a huge outcome; explore what you get, and then you can clear this cell outcome

# %%
# Usually, there are two labels into the web server response the metadata, and the data; we will use the data label
# to get all attributes included. 
rental_data = data['data']
rental_data
# See the structure of the data, you can see
# 'attribute':'value' structure
# each {} define one row or one element
# Again, here you will get a huge outcome; just explore what you get, and then you can clear this cell outcome

# %%
rental_pd = pd.DataFrame(rental_data)
#Can you guess what we are doing here?
rental_pd.head()

# %%
rental_pd.shape

# %%
rental_pd.columns

# %%
# Check for NaN in the coordinates column
nan_in_column_Lat = rental_pd['startPlaceLat'].isna().any()
nan_in_column_Long = rental_pd['startPlaceLong'].isna().any()

print(nan_in_column_Lat,nan_in_column_Lat)

# Alternatively, you can use the following to count NaN values
nan_in_column_Lat = rental_pd['startPlaceLat'].isna().sum()
nan_in_column_Long = rental_pd['startPlaceLong'].isna().sum()
print(nan_in_column_Lat,nan_in_column_Lat)

# %%
clean_rental_pd = rental_pd.dropna(subset=['startPlaceLat', 'startPlaceLong', 'endPlaceLat','endPlaceLong'])
clean_rental_pd.info()

# %%
gdf_bikes_start = gpd.GeoDataFrame(clean_rental_pd, geometry=gpd.points_from_xy(clean_rental_pd['startPlaceLong'], clean_rental_pd['startPlaceLat']))
#gdf_bikes_end = gpd.GeoDataFrame(clean_rental_pd, geometry=gpd.points_from_xy(clean_rental_pd['endPlaceLong'], clean_rental_pd['endPlaceLat']))

# Print the GeoDataFrame
gdf_bikes_start.info()
# Do we need all those columns? And you see, there is also a lot of pre-processing to do with all the object Dtype

# %%
gdf_bikes_start.plot()

# %%
gdf_bikes_start.crs

# %%
gdf_bikes_start = gdf_bikes_start.set_crs("EPSG:4326")

# %%
gdf_bikes_start.plot()

# %%
gdf_bikes_start.dtypes

# %%
keep_cols = [
    "startDate",
    "startPlaceId",
    "startPlaceName",
    "durationSeconds",
    "isInvalid",
    "price",
    "isEbike",
    "startPlaceLat",
    "startPlaceLong",
    "geometry",
]
gdf_bikes_start = gdf_bikes_start[keep_cols]
gdf_bikes_start.head()

# %%
gdf_bikes_start.info()

# %%
gdf_bikes_start.startPlaceId = gdf_bikes_start.startPlaceId.astype(int)
gdf_bikes_start.startPlaceName = gdf_bikes_start.startPlaceName.astype(str)
gdf_bikes_start['startDate'] = pd.to_datetime(gdf_bikes_start['startDate'], format='%Y-%m-%dT%H:%M:%SZ')

# %%
gdf_bikes_start.dtypes
#gdf_bikes_start['startPlaceName'].unique()

# %%
gdf_bikes_start.head()

# %%
from sklearn.cluster import KMeans

num_clusters = 5
kmeans_collection = KMeans(n_clusters=num_clusters, random_state=42)
gdf_bikes_start['kmeanscluster'] = kmeans_collection.fit_predict(gdf_bikes_start[['startPlaceLong', 'startPlaceLat']])

# %%
gdf_bikes_start.head()

# %%
gdf_bikes_start.plot(column='kmeanscluster')

# %% [markdown]
# ## Beginning of work done for challenge 2; part 1.

# %%
# Part No 1:

# 1. Using the same workflow previously described, now calculate the clustered areas for the GeoPandasDataFrame gdf_bikes_end
# 2. Make sure you don't have any NaN in your columns, add a CRS, clean up the unnecessary attributes, calculate the cluster values, and plot a map of 4 calculated clusters for the return locations.

# I first create a GeoDataFrame gdf_bikes_end from the DataFrame clean_rental_pd that i previously created in the exercises with an additional geometry column 
# created from the Point geometries generated using gpd.points_from_xy(...). 
# The geometry parameter specifies the name of the column that will contain the Point geometries.
# With gpd.points_fromxy(...) I create a GeoSeries of Point geometries from the longitude and latitude coordinates provided in clean_rental_pd. Each Point  represents a location specified by the longitude and latitude coordinates.
gdf_bikes_end = gpd.GeoDataFrame(clean_rental_pd, geometry=gpd.points_from_xy(clean_rental_pd['endPlaceLong'], clean_rental_pd['endPlaceLat']))
# printing a summary of the dataframe created
gdf_bikes_end.info()

# %%
# i check what this looks like to see that the data looks right and for later isolation
gdf_bikes_end.head()

# %%
# setting the CRS of the GeoDataFrame to EPSG 4326,
gdf_bikes_end = gdf_bikes_end.set_crs("EPSG:4326")

# %%
# given that I cant .explore() given the issue of my local library i will 
# use gdf_bikes_end.plot()to simply plot what i have just done in the revious step 
# as well as to check the data was created accordingly and properly.
gdf_bikes_end.plot()

# %% [markdown]
# ![image.png](attachment:3fb6f723-0aed-4394-831a-682bfe8f32ee.png)

# %% [markdown]
# > Although this plot does not specify any column data, i did not plot it for analysis purposes but more to clarify that the data seems ok to continue my analysis. I am therefore leaving it in for descriptive representation of my step by step.

# %%
# To manipulate the end data specifically, i isolate it from the rest and define a list named 
# keep_cols_end which contains the names of the columns from the original data gdf_bikes_end I want to keep in your GeoDataFrame.
# I looked at the column titles in the .head() and .info.() cells ran earlier and picked accordingly to specifically retain the name titles highlighted in red below.
keep_cols_end = [
    "endDate",
    "endPlaceId",
    "endPlaceName",
    "durationSeconds",
    "isInvalid",
    "price",
    "isEbike",
    "endPlaceLat",
    "endPlaceLong",
    "geometry"
]
gdf_bikes_end = gdf_bikes_end[keep_cols_end]
# I then display the first few rows of the resulting GeoDataFrame gdf_bikes_end containing only the selected columns using the head() method to check it has performed effectively. 
gdf_bikes_end.head()

# %%
# Here i do the same but with .info() to provide a more concise summary 
gdf_bikes_end.info()

# %%
# In the following line i want to convert the 'endPlaceId' column in the GeoDataFrame gdf_bikes_end to integer data type. 
# I use .astype(int) method to  to do so.
gdf_bikes_end.endPlaceId = gdf_bikes_end.endPlaceId.astype(int)
# I then want to convert the 'endPlaceName' column to string data type. 
# I use .astype(str) method to do so.
gdf_bikes_end.endPlaceName = gdf_bikes_end.endPlaceName.astype(str)
# I then want to convert the 'endDate' column to datetime data type.
# I use pd.to_datetime() function to do so and specify the format of the datetime string into year, month, day, hour minute, seconds and timezone.
gdf_bikes_end['endDate'] = pd.to_datetime(gdf_bikes_end['endDate'], format='%Y-%m-%dT%H:%M:%SZ')

# %%
# here i check with .dtypes the data types of each column
gdf_bikes_end.dtypes

# %%
# with .head() i want to inspect the changes made to the data types and see a preview of the data after the conversion
gdf_bikes_end.head()

# %%
# i now want to start creating clusters on the geographical coordinates 'endPlaceLong' and 'endPlaceLat' of the end locations of bike rentals 
# importing KMeans class from the sklearn.cluster library
from sklearn.cluster import KMeans
# specifying the number of clusters to 4

num_clusters = 4

# I create an object (kmeans_collection) with the specified number of clusters created in the previous step
# and a random state of 42 for reproducibility.
kmeans_collection = KMeans(n_clusters=num_clusters, random_state=42)

# I assign the cluster labels obtained from k-means clustering to a new column named 'kmeans_cluster_end' 
# and apply it to 'endPlaceLong', 'endPlaceLat' using the fit_predict() method.
gdf_bikes_end['kmeans_cluster_end'] = kmeans_collection.fit_predict(gdf_bikes_end[['endPlaceLong', 'endPlaceLat']])

# %%
# here i want to check that the new columnkmeans_cluster_end has been added to the gdf_bikes_end data.
gdf_bikes_end.head()

# %%
# and i finally .plot() the result. instead of .explore() since technical issues from my local libraries dont allow me to.
# for this, i specify that the column i want to look at is kmeans_cluster_end to see the changes.
gdf_bikes_end.plot(column='kmeans_cluster_end')

# %% [markdown]
# ![image.png](attachment:e1c66eac-3fbf-4bd4-a598-8904e000b2fc.png)

# %% [markdown]
# > I have been importing screenshots of the results of my operations to diminish the weight of cell outputs since later maps are very heavy.
# It seems that the data from this challenges outputs has performed correctly as the clusters column was successfully made and calculated looking at the GeoPandasDataFrame gdf_bikes_end.

# %% [markdown]
# ## Part 2
# 1. Using the Glasglow Open Data API ( Transit) https://developer.glasgow.gov.uk/api-details#api=traffic&operation=traffic-sensor-locations fetch all the sensor locations in the city.
# 2. Map the sensor

# %%
# Importing the libraries although some of them have already been imported, it is easier to keep track again.
# Requests will alow HTTP requests to web servers, pandas data manipulation and analysis and geopandas to work with geospatial data.

import requests
import pandas as pd
import geopandas as gpd

# Let's describe the url with the traffic sensors data and name it traffic_sensors_url.
traffic_sensors_url = "https://api.glasgow.gov.uk/traffic/v1/movement/sites"
# Making the query to the web server, using the Get method from the requests library.
response = requests.get(traffic_sensors_url)
response

# %%
# Once i have had the response from the web server, I need to translate that into a format I can manipulate, this will be JSON.
# I assign the translated information to sensors_data and link it to the data in the response object just created.
sensors_data = response.json()
# Displaying sensors_data to look at the extracted JSON data in dictionary form.
sensors_data

# %%
# I continuously got a TypeError: list indices must be integers or slices, not str
# Through research i found that a possibility may be to convert the list to a dictionary-like structure
# When displaying sensors_data above it does not appear in dictionary form but in a list of dictionaries form, so here I;
# Create a dictionary named sensor_data_dict where the key is 'sensors_data' and the value is sensors_data,
# This last one contains JSON data in dictionary format retrieved from a web server, as i performed in the previous steps.
sensor_data_dict = {'sensors_data': sensors_data}

# Accessing the 'sensor_data' key to retrieve the sensors data from the dictionary sensor_data_dict 
# and I name it trafficsensor_locdata
trafficsensor_locdata = sensor_data_dict['sensors_data']

# Printing the  data
print(trafficsensor_locdata)

# %%
# I now will turn the trafficsensor_locdata into DataFrame form
trafficsensor_pd = pd.DataFrame(trafficsensor_locdata)
#displaying the data frame to see if it worked
trafficsensor_pd

# %%
# I'm ging to check the dimensions of the data i just created, it should be 1275 rows and 3 columns as indicated above
trafficsensor_pd.shape

# %%
# Having a look at the summary of the DataFrame with .info()
# it indicates 1275 non-null, indicating this number of rows to have non-null values. Since this is the total it is not needed to clean the data of Nan values.
trafficsensor_pd.info()

# %%
# The following code extracts the latitude and longitude information from the nested dictionaries in the 'from' and 'to' columns, 
# and creates separate columns for latitude and longitude, for this i have to normalize the attribute 'from' to extract long and lat values
normalised_trafficfrom =pd.json_normalize(trafficsensor_pd['from'])
# Checking what this has done
normalised_trafficfrom

# %%
# checking the types of data for each column
normalised_trafficfrom.dtypes

# %%
# I will now create a new DataFrame named fromtrafficsensor_pd by passing the variable normalised_trafficfrom as input to the pd.DataFrame().
fromtrafficsensor_pd = pd.DataFrame(normalised_trafficfrom)
#Can you guess what we are doing here?
fromtrafficsensor_pd

# %%
# Creating a geo data frame, for this I;
# Import the Point class from the shapely.geometry package to represent a point in space with x and y coordinates.
from shapely.geometry import Point
# Then I create a list of latitude and longitude pairs
geom = [Point(xy) for xy in zip(fromtrafficsensor_pd.lat, fromtrafficsensor_pd.long)] #create a list of latitude, longitude pairs
# With this, I can create the GeoDataFrame named traffic_sensors_gdf where I;
# refer to fromtrafficsensor_pd the dataframe i want to plot, specify the coordinate reference system 
# EPSG:4326, and set then set the geometry parameter to geom created in the previous step as the list of point objects.
traffic_sensors_gdf = gpd.GeoDataFrame(fromtrafficsensor_pd, crs='EPSG:4326', geometry=geom)

# %%
# Creating a visual representation of the spatial distribution of traffic sensors.
# Again, my local libraries' technical issues only allow me to .plot(). This way i can see if the data has processed correctly.
# Importing the necessary libraries
# import geopandas as gpd is not necessary because it was imported earlier
import matplotlib.pyplot as plt

# Plotting the geometry column (Point objects representing traffic sensor locations) GeoDataFrame with 
# customized options; figure size, colormap, legend, and axis labels and then displaying the plot with plt.show.
traffic_sensors_gdf.plot(figsize=(10, 10), cmap='viridis', legend=True)
plt.title('Traffic Sensor Locations')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()

# %% [markdown]
# 3. Find the WorkingZones and Calculate/Map the areas with more and fewer sensors distributed in the city.
# 4. You will need:
# - Get two separate Geopandas DataFrames, one for the traffic sensors and another one for the WorkingZones.
# Using sJoin ( Spatial Join) https://geopandas.org/en/stable/docs/reference/api/geopandas.sjoin.html calculate the overlay of sensors and polygons.
# - Using group_by https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.groupby.html to count the number of sensors per WorkingZone
# - Make sure you add the counts into the WorkingZone polygons of Glasgow so you can create a map of Zones with more and fewer traffic sensors.
# Of course, you will need extra steps where you manipulate the data and extract what you need, for instance, clipping the Working Zones only for Glasgow.
# 5. Make sure you comment on your code and describe how you are manipulating the data.

# %%
#Reading the shp file - creates a data frame called working_zones
working_zones = gpd.read_file("/Users/carlota/Documents/Documents - Carlota’s MacBook Air/UA Repo/Assigment 1 - 200017209/Lab 2/WorkplaceZones2011Scotland.shp")
working_zones.head()

# %%
# checking the crs of this data set.
working_zones.crs

# %%
# Change the CRS to EPSG:4326 to match traffic sensors geodataframe
working_zones = working_zones.to_crs('EPSG:4326')

# %%
# checking that it has been converted into EPSG:4326
working_zones_gdf.crs

# %%
# Creating a geo data frame, for this I;
# The dataset already has a geometry column with a list of latitude and longitude pairs
# With this, I can create the GeoDataFrame named working_zones_gdf where I;
# refer to working_zones dataframe i want to plot, specifying the coordinate reference system 
# EPSG:4326 so that it matches the traffic sensors, and set then set the geometry parameter to 'geometry' which as shown in the table above has longitude and latitude added.
working_zones_gdf = gpd.GeoDataFrame(working_zones, crs='EPSG:4326', geometry='geometry')

# %%
# Filtering the working_zones to only include Glawgow zones labeled as "WZCD"
working_zones_wzcd = working_zones_gdf[working_zones_gdf['WZCD'] == 'WZCD']

# Perform the spatial join with the filtered working_zones_wzcd GeoDataFrame
joined_gdf = gpd.sjoin(traffic_sensors_gdf, working_zones_wzcd, how='inner', op='within')

# Resulting joined_data will contain only the traffic sensors that are within the "WZCD" zones
print(joined_gdf.head())

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# Plotting the joined_data GeoDataFrame
joined_gdf.plot(ax=ax, color='blue', markersize=5)

# Setting plot title and labels specific to the dataframes I'm looking at
plt.title('Traffic Sensors within WZCD Zones')
plt.xlabel('Longitude')
plt.ylabel('Latitude')

# Show the plot
plt.show()

# %% [markdown]
# > This last part of the challenge was quite challenging to perform considering the technical issues with my local libraries. This impeded me from checking how the data was evolving throughout the steps, to check if the dataframes had properly converted into geodataframes, whether clipping the Working Zones only for Glasgow was succesful in creating a new geodataframe excluding the rest of the areas and finally if the layers had been properly joined with .sjoin().

# %% [markdown]
# # Lab Workbook No 3: Geovisualization Techniques - Data Viz.

# %% [markdown]
# # Challenge 1
#
# **What happens if you have non-numerical attributes?**
#
# Please extend the `data_description` function to only accept numerical columns and calculate mean and counts. The outcome should be a table with Mean and Counts per Column.
#
# > Tip: Check this function in pandas to filter the numerical values. https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.select_dtypes.html#pandas.DataFrame.select_dtypes
# > Here some extra resources of creating function in python https://www.geeksforgeeks.org/python-functions/?ref=lbp

# %%
# The following part includes work from the exercises previous to the challenge. I have kept these in 
# for me to be able to understand the process and origins of data, avoid confusion and 
# for the purpose of transparently showing my working process. The challenge working process and results will be signalized.
# This will allow me to go back and understand the original dataframes once the technical issues 
# have been looked at to plot the process of data manipulation and changes in data frames as i go through the steps to derive the challenge.

# %%
# work previous to the challenge needed to run the necessary answers
import pandas as pd

listings =pd.read_csv("/Users/carlota/Documents/Documents - Carlota’s MacBook Air/UA Repo/Assigment 1 - 200017209/Lab 3/listings.csv")


#Show column headings
listings.head()

# %%
# Subset data
subset_listings = listings[['id', 
                            'neighbourhood_cleansed',
                            'latitude',
                            'longitude',
                            'property_type',
                            'room_type',
                            'bedrooms',
                            'price',
                            'number_of_reviews']]

# We need to do some cleaning...There are some weird characters $ and , then convert the outcome to a dtype numeric.
# I use multiple functions in one line, but the key is using .loc and replace., check this link for more information.
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.loc.html
subset_listings.loc[subset_listings.index, 'price'] = subset_listings['price'].replace('[\$,]', '', regex=True).astype(float)

# Remove any records that are not complete
subset_listings = subset_listings.dropna()

# Let's see the results.
subset_listings.head()

# %%
subset_listings.dtypes

# %%
# Generate descriptive statistics
descriptive_stats = subset_listings.describe()
descriptive_stats

# %%
descriptive_stats_non_numerical = subset_listings.describe(exclude='number')
descriptive_stats_non_numerical

# %%
neighborhood_counts = subset_listings['neighbourhood_cleansed'].value_counts()
neighborhood_counts

# %%
# Here for the complete doc https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.crosstab.html 
cross_tabulation = pd.crosstab(subset_listings['neighbourhood_cleansed'], subset_listings['bedrooms'])
cross_tabulation

# %%
cross_tabulation.info()

# %%
Sum_by_area = subset_listings.groupby('neighbourhood_cleansed')['price'].mean().reset_index()
Sum_by_area

# %%
# data_description function
def data_description(x):
    stats = {'M': x.mean(), 'S': len(x)}
    return stats

# %%
result = data_description(subset_listings.price)
print(result)

# %%
# The following is the working process extending the `data_description` function to only accept 
# numerical columns and calculate mean and counts. The goal is to achieve an outcome 
# of a table with Mean and Counts per Column.

# %%
# importing library (although it has already been done in previous challenges, 
# it allows me to keep track of what I'm doing)
import pandas as pd
import numpy as np
# defining a function called data_description where x serves as the input to later add the subset_listing 
# and create a mean and count table for every column variable.
def data_description(x):
    # Selecting only numerical columns
    numerical_cols = x.select_dtypes(include=np.number)
    
    # Calculating mean and count for each numerical column using .mean() and .count() methods 
    # under a new dataframe called 'stats' to then be returned as an output.
    stats = pd.DataFrame({
        'Mean': numerical_cols.mean(),
        'Counts': numerical_cols.count()
    })
    
    return stats
# data_description is called with subset_listings DataFrame as input to derive a table with mean and counts per column of the dataset
result_stats = data_description(subset_listings)
result_stats

# %%
# repeating the same language for the original listings set.
import pandas as pd
import numpy as np
# defining a function called data_description where x serves as the input to later add the listing 
# and create a mean and count table for every column variable.
def data_description(x):
    # Selecting only numerical columns
    numerical_cols = x.select_dtypes(include=np.number)
    
    # Calculating mean and count for each numerical column using .mean() and .count() methods 
    # under a new dataframe called 'stats' to then be returned as an output.
    stats = pd.DataFrame({
        'Mean': numerical_cols.mean(),
        'Counts': numerical_cols.count()
    })
    
    return stats
# data_description is called with listings DataFrame as input to derive a table with mean and counts per column of the dataset
result_stats = data_description(listings)
result_stats

# %% [markdown]
# # Challenge 2
#
# Now is your turn to find, read, process and then make a comprehensive descriptive statistics analysis based on the previous resources and others you might need to look at. Create insightful visualizations combining both maps and charts to convey meaningful information about a chosen city.
#
# 1. Define a problem within the urban environment and choose a dataset related to urban life or city dynamics. This could include data on crime rates, housing prices, transportation, demographics, or any other urban-related dataset.
# 2. Get the data ideally using an **API, or web services**. But it's fine if you need to download the data. Describe why you had to use the traditional  method.
# 3. Work with the data cleaning and pre-processing, check for missing values, convert data types, and perform any other necessary preprocessing steps. You have the code for that in this and previous labs.
# 4. Use Pandas to calculate descriptive statistics such as `mean`, `median`, `standard deviation`, and other relevant measures. Explore `correlations` between different variables (Include at least one `univariate` and `bivariate` plots)
# 6. Create at least one (or more) interactive map to visualize spatial aspects of the data. For example, plot crime rates across different neighbourhoods or visualize housing prices.
# 7. Complement with additional charts (line charts, bar charts, etc.) to extend the map and highlight key trends or patterns in the data.
# 8. As always, document well what you are doing and how you use `descriptive statistics and map visualizations` to extract insights from the data.
# > You could try explaining any observed patterns, trends, or correlations, whether they are spatial or non-spatial. **Keep in mind** the defined problem and whether your analysis provides the required insights (Your conclusion could be that you need more data or another type of analysis)

# %%
# 1. Define a problem within the urban environment and choose a dataset related to urban life or city dynamics. 
# This could include data on crime rates, housing prices, transportation, demographics, or any other urban-related dataset.

# The dataset i have chosen looks at parking meters locations in bloomington, IN. After i found this dataset,
# I considered the relevance of parking demand analysis in understanding not only the utilization of 
# parking spaces, but to analyze parking demand patterns in different areas of the city, 
# identify high-demand areas, and assess the effectiveness of existing parking infrastructure.
# I considered its further relevance in how there are cities that have implemented parking pricing 
# strategies using specific parking meters with differing prices as part of their efforts to 
# manage traffic, reduce congestion, and encourage sustainable transportation modes.
# downloaded from data.world, https://data.world/city-of-bloomington/2cd1715a-1796-4c17-b60f-233e0c4ddcd9/workspace

# %%
# 2. Get the data ideally using an API, or web services. But it's fine if you need to download the data. 
# Describe why you had to use the traditional method.
# I downloaded 
import geopandas as gpd
import matplotlib.pyplot as plt
parking_meters = gpd.read_file('/Users/carlota/Documents/Documents - Carlota’s MacBook Air/UA Repo/Labs/Lab 3/bloomington-parkingmeters/ParkingMeters.shp')
parking_meters.head()

# %%
# checking the types of variables
parking_meters.dtypes

# %%
# Since I cannot explore, I am plotting the dataset to see if it can provide me an overview of the datasetimported 
parking_meters.plot()
plt.title('Parking Meters in Bloomington')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()

# %%
# 3. Work with the data cleaning and pre-processing, check for missing values, convert data types, and perform any other necessary preprocessing steps. 
# You have the code for that in this and previous labs.
import geopandas as gpd
# it already has existing geometry values, so there is no need to re-create another one. Now i will create a GeoDataFrame from the parking_meters dataset
geo_parkingmeters = gpd.GeoDataFrame(parking_meters, geometry='geometry', crs=parking_meters.crs)

# %% [markdown]
# geo_parkingmeters.plot()

# %% [markdown]
# ![image.png](attachment:2a6bac82-1eec-4735-ae97-ea5674ffdc28.png)

# %%
# checking the crs's of the data and derivative geo data frames
print(parking_meters.crs)
print(geo_parkingmeters.crs)

# %%
# Before making any spatial analysis we need to project the data, For Bloomington, Indiana, the EPSG code for the corresponding UTM zone should be used. Bloomington is situated in Monroe County, Indiana, which falls within UTM zone 16N.
# The EPSG code for UTM zone 16N is EPSG:26916.
projected_parking_meters = parking_meters.to_crs('EPSG:26916')
projected_geo_parkingmeters = geo_parkingmeters.to_crs('EPSG:26916')
print(projected_parking_meters.crs)
print(projected_geo_parkingmeters.crs)

# %%
# Now, i will make a buffer of 200m from all the parking meters.
parkingmeter_buffers = projected_geo_parkingmeters.buffer(200)
parkingmeter_buffers.plot()

# %% [markdown]
# ![Screenshot 2024-02-22 at 10.22.33.png](attachment:f2558417-af9b-4759-9087-17d6809b0eb5.png)

# %%
# This outcome does not have an ID, so we can easily create one. 
# Also, the outcome is a GeoSeries which cannot be used in a buffer analysis. You can transform it using the geometry values.

parkingmeter_buffers = gpd.GeoDataFrame(geometry=parkingmeter_buffers, crs = 'EPSG:26916')
parkingmeter_buffers['buffer_id'] = range(len(parkingmeter_buffers))
parkingmeter_buffers.head()

# %%
#checks whether the variable parkingmeter_buffers is a GeoDataFrame from the geopandas library.
print(isinstance(parkingmeter_buffers, gpd.GeoDataFrame))

# %%
# Converting GeoSeries to GeoDataFrame since Geopandas is what provides two spatial-join functions
# This following step looks at GeoDataFrames containing spatial data related to parking meters and 
# buffers around them, respectively, and performs a spatial join operation between the two.
spatialmeter_result =  projected_geo_parkingmeters.sjoin(parkingmeter_buffers, how="inner", predicate='intersects')
spatialmeter_result.head()

# %%
# The following code groups the dataframe by the values in the 'buffer_id' column and calculates the size of each group, which represents the count of parking meters within each buffer.
parkingmeters_per_buffer = spatialmeter_result.groupby('buffer_id').size().reset_index(name='parkingmeters_per_buffer')
parkingmeters_per_buffer

# %%
# And I can try to we can pick one of the buffer areas to plot it. For instance the 1620.
filtered_meterrow = spatialmeter_result[spatialmeter_result['buffer_id'] == 1620]
filtered_meterrow.plot()

# %% [markdown]
# ![image.png](attachment:39e9f98e-8a74-48c7-a6e3-949b6df314f0.png)

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(8, 8))

# I can now plot the buffer areas and its listings
filtered_meterbuffer = parkingmeter_buffers[parkingmeter_buffers['buffer_id'] == 194].plot(ax=ax, color="#D4D4D4", alpha=0.5)

# I can overlay all traffic meters within the filtered buffer
filtered_meterrow.plot(ax=ax, marker='o', color="#FF4500", markersize=5, alpha=0.7)

# Specifying and making the the plot nicer
ax.set_title("Parking meters within Buffer - ID 1620")
plt.show()

# Plotting a histogram of the distribution of parking metter attribute
plt.figure(figsize=(6, 4))
filtered_meterrow.plot(kind='hist', bins=20, color='#FF4500', alpha=0.7)
plt.title('Distribution of Parking Meters within Buffer - ID 1620')
plt.show()

# %% [markdown]
# ![image.png](attachment:cbdb3acb-da48-4f26-916b-7292704f711a.png)
# ![image.png](attachment:990ff92b-e2e2-4df3-ab64-f08594bf0dab.png)

# %%
# importing Folium
import folium
from folium import plugins
from folium.plugins import MeasureControl
from branca.colormap import linear
from branca import colormap
from branca import colormap as cm

# %%
# Creating a folium Map object centered around Bloomington, Indiana
m = folium.Map([39.1653, -86.5264], zoom_start=12)
# location=filtered_meterrow[['geometry']]

# %%
# Extract the latitude and longitude coordinates from each Point object
location = [(point.y, point.x) for point in filtered_meterrow['geometry']]

# Debugging: Printing locations list to inspect coordinates
# print(locations)

# %%
plugins.MarkerCluster(location).add_to(m)
m
# This was performed, however the filtered meter row is not being appplied to the Bloomington map. 
# The bloomington map is centered and the data set is applied to it in the cell above.

# %%
# 4. Use Pandas to calculate descriptive statistics such as mean, median, standard deviation, and other relevant measures. 
# Explore correlations between different variables (Include at least one univariate and bivariate plots)
#Add your code, here

import pandas as pd

def parking_meters_description(data):
    # Select only numerical columns
    numerical_cols = data.select_dtypes(include='number')
    
    # Calculate descriptive statistics for each numerical column
    stats = pd.DataFrame({
        'Mean': numerical_cols.mean(),
        'Median': numerical_cols.median(),
        'Standard Deviation': numerical_cols.std(),
        'Minimum': numerical_cols.min(),
        'Maximum': numerical_cols.max(),
        'Count': numerical_cols.count(),
        'Missing Values': numerical_cols.isnull().sum(),
    })
    
    return stats

# Assuming 'parking_meters' is your DataFrame containing parking meter data
result_stats = parking_meters_description(parking_meters)
print(result_stats)

# %%
# Generate descriptive statistics
descriptive_stats = parking_meters.describe()
descriptive_stats

# %%
#It is also possible to create cross-tabulations; showing the frequency of two attributes in this case zone in the city and meter type
# this way we can look at what the correlation between the type of meter and location is.
# Here for the complete doc https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.crosstab.html 
meterscross_tabulation = pd.crosstab(parking_meters['ips_area'], parking_meters['meter_type'])
meterscross_tabulation

# %%
# i can do so similarly by checking the count of active or removed meter types 
anothermeterscross_tabulation = pd.crosstab(parking_meters['meter_type'], parking_meters['meter_stat'])
anothermeterscross_tabulation

# %%
# and similarly to how many active or removed sensors are in which areas to also check which have the most/least traffic meters.
traffmeterscross_tabulation = pd.crosstab(parking_meters['ips_area'], parking_meters['meter_stat'])
traffmeterscross_tabulation

# %%
# 6. Complement with additional charts (line charts, bar charts, etc.) to extend the map and highlight key trends or patterns in the data.
# To so, i am going to plot the cross tabulation created in the previous steps to graphically explore 
# the results. Here we can see what types of meter can be found in which areas.
# the highest number of M type meter types is shown to be present, most frequently in zones 1 to 5.
# the technical issues dont allow me to vsualize this on a map, but it ould be interesting to look at what 
# the correlation is to the zones, the reasons for having a more frequent presence of this type of meter 
# and how it relates to external factors of the area such as congestion, crowdness and relevance of the 
# area (perhaps it is a shopping centre zone), etc.
meterscross_tabulation.plot()

# %% [markdown]
# ![image.png](attachment:c3e7a356-833c-49af-b446-596635ed8440.png)

# %%
# Similarly, here we can see which meters are active or have been removed and what their type is to 
# investigate a correlation in the decision making of their implementation.This can be valuable information
# when investigation why M metertype is shown to be the most active but is also displayed to have the only peak
# in removed. this M parking meter might have a specific correlation to the type of prices it holds, information it may provide,
# accessibility, etc., according to what the authorities try to achieve with their distribution of parking meters. 
# This may be control of traffic congestion, avoidance of use of private cars for environmental reasons, or others.
anothermeterscross_tabulation.plot()

# %% [markdown]
# ![image.png](attachment:920315c5-8f7b-4df6-835d-a01c3f8b595c.png)

# %% [markdown]
# # Challenge 3
#
# 1. Go to https://data.cityofnewyork.us/Public-Safety/Motor-Vehicle-Collisions-Crashes/h9gi-nx95/about_data
# 2. Get the data for Motor Vehicle Collisions - Crashes Jan 2024. The dataset contains 2.06 M of records.
# 3. Use the API endpoint to map the data (e.g. https://data.cityofnewyork.us/resource/h9gi-nx95.json)
#    ![image.png](attachment:8b7103ca-9191-4b67-97c2-0cfb8b8468fc.png)
# 4. Customize the map by representing the data by `number_of_persons_killed` and `number_of_cyclist_killed`
# 5. Finally, calculate descriptive statistics for at least two attributes, such as `mean`, `standard deviation`, and other relevant measures 6. Justify/Describe the attribute selection.
# 7. Plot correlations between the chosen attributes and create `univariate` and/or `multivariate` charts to justify your insights.
#    > Please take note that the dataset includes various numerical values. Hence, each student's attribute selection, justification, charts, and maps are expected to vary.

# %%
# 1. Go to https://data.cityofnewyork.us/Public-Safety/Motor-Vehicle-Collisions-Crashes/h9gi-nx95/about_data
# 2. Get the data for Motor Vehicle Collisions - Crashes Jan 2024. The dataset contains 2.06 M of records.
# 3. Use the API endpoint to map the data (e.g. https://data.cityofnewyork.us/resource/h9gi-nx95.json)
# https://data.cityofnewyork.us/resource/h9gi-nx95.json
# As I encountered issues in to use the API endpoint to the map, I downloaded the csv zipfile which I then obstructed to be able to open up the data 
# Reading downloaded csv file Motor-vehicle-collisions-crashes.
vehicle_collisions = pd.read_csv('/Users/carlota/Documents/Documents - Carlota’s MacBook Air/UA Repo/Assigment 1 - 200017209/Lab 3/Motor_Vehicle_Collisions_-_Crashes_20240217/Motor_Vehicle_Collisions_-_Crashes_20240217.csv')

# %%
# checking number of records to verify that the data was read correctly
vehicle_collisions.shape

# %%
# Displaying the first few rows of the concatenated DataFrame
vehicle_collisions.head()

# %%
# Checking for a summary of the provided columns
vehicle_collisions.columns

# %%
# Customizing layer, lets explore the data columns i want to focus on by looking at the count of values
# Let's initially check how many categories we have in this number of persons kille column.
persons_killed = vehicle_collisions['NUMBER OF PERSONS KILLED'].value_counts()
persons_killed

# %%
# Customizing layer
# Let's initially check how many categories we have in this number of cyclists killed column.
cyclist_killed = vehicle_collisions['NUMBER OF CYCLIST KILLED'].value_counts()
cyclist_killed

# %%
# After the initial pre-processing, you have significantly less amount of data records.
# adding geometry to map
import geopandas as gpd
geometry = gpd.points_from_xy(vehicle_collisions['LATITUDE'], vehicle_collisions['LONGITUDE'])
geo_collisions = gpd.GeoDataFrame(vehicle_collisions, geometry=geometry, crs='EPSG:4326')
geo_collisions.head()

# %%
geo_collisions.shape

# %%
# Subsetting data to look at every data colum in relation to number of persons and cyclists killed
subset_collisions = geo_collisions[['CRASH DATE', 
                            'CRASH TIME',
                            'LATITUDE',
                            'LONGITUDE',
                            'BOROUGH',
                            'ZIP CODE',
                            'LOCATION',
                            'ON STREET NAME',
                            'COLLISION_ID',
                            'NUMBER OF PERSONS INJURED',
                            'NUMBER OF CYCLIST KILLED']]

# Remove any records that are not complete
subset_collisions = subset_collisions.dropna()

# Let's see the results.
subset_collisions.head()

# %%
# The technical issues impede me from exploring properly what this subset creating a new smaller 
# dataframe with the data i consider relevant for the inspection of variable columns number of persons 
# and cyclists killed. For this, it is quite challenging to evaluate the data manipulation and plot does 
# not provide me an accurate or effective way of reviewing this, as can be seen below.
subset_collisions.plot()

# %% [markdown]
# ![image.png](attachment:1a7bdc0e-7d16-4865-b3bc-27dc097600af.png)

# %%
# Given the circumstances, i attempt to still evaluate the data in a different way by grouping the 
# variables in search for an outcome that gives me the count of persons/cyclists killed and frequency of number of deaths per count.
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# Grouping by number of persons killed and number of cyclists killed, for this i refer to the original data previous to the subset created.
persons_cyclists_killed = geo_collisions.groupby(['NUMBER OF PERSONS KILLED', 'NUMBER OF CYCLIST KILLED']).size().reset_index(name='count')

# %%
persons_cyclists_killed

# %%
# since the data seems to have quite a few NaN values that we only cleaned when performing the subset, i drop the Nan values to calculate and process this again only including non-null values.
# Dropping records with NaN values in 'number_of_persons_killed' and 'number_of_cyclist_killed' columns
subset_collisions = persons_cyclists_killed.dropna(subset=['NUMBER OF PERSONS KILLED', 'NUMBER OF CYCLIST KILLED'])

# Checking for NaN values again
subset_collisions.head()

# %%
# I attempt to try another way of exploring the data without using the plotting libraries that my technical issues dont allow me to plot.


# For this i drop records with NaN values in 'number_of_persons_killed' and 'number_of_cyclist_killed' columns in the original data frame
subset_collisions = vehicle_collisions.dropna(subset=['NUMBER OF PERSONS KILLED', 'NUMBER OF CYCLIST KILLED'])

# Checking for NaN values again to see if the previous step performed properly
subset_collisions.head()

# %%
# checking hw much has the number of records decreased.
subset_collisions.shape

# %%
# Customizing the cleared from Nan values plot and specifying number of persons and cyclists killed 
# to see if this can give me a better understanding.
plt.figure(figsize=(10, 6))
sns.scatterplot(data=persons_cyclists_killed, x='NUMBER OF PERSONS KILLED', y='NUMBER OF CYCLIST KILLED', size='count', sizes=(50, 300), legend=False)
plt.title('Motor Vehicle Collisions - Persons vs Cyclists Killed')
plt.xlabel('Number of Persons Killed')
plt.ylabel('Number of Cyclists Killed')
plt.show()

# %% [markdown]
# ![image.png](attachment:44db54b3-c151-4fd7-9dfc-9e74151fbcb3.png)

# %%
# Finally, I calculate descriptive statistics for at least two attributes, such as mean, 
# standard deviation, and other relevant measures. 
# the other measures apart from mean and standard deviation I have chosen are min, max and count values 
# as i find them to be the most statistically relevant.

#Add your code, here
import pandas as pd
import numpy as np

def data_description(df):
    # Calculate mean, standard deviation, min, max, and count for each numerical column
    stats = pd.DataFrame({
        'Mean': persons_cyclists_killed.mean(),
        'Standard Deviation': persons_cyclists_killed.std(),
        'Min': persons_cyclists_killed.min(),
        'Max': persons_cyclists_killed.max(),
        'Counts': persons_cyclists_killed.count()
    })
    
    return stats

collisions_stats = data_description(geo_collisions)
collisions_stats

# %%
# since matplotlib.pyplot as plt, i will check if the plot is any different.
import matplotlib.pyplot as plt

# Assuming 'motor_vehicle_collisions' is your DataFrame containing the data

# Customize the plot
plt.figure(figsize=(10, 6))

# Scatter plot with 'number_of_persons_killed' and 'number_of_cyclist_killed' as x and y coordinates
plt.scatter(geo_collisions['NUMBER OF PERSONS KILLED'], geo_collisions['NUMBER OF CYCLIST KILLED'])

# Set labels and title
plt.xlabel('Number of Persons Killed')
plt.ylabel('Number of Cyclists Killed')
plt.title('Motor Vehicle Collisions - Persons vs Cyclists Killed')

# Show plot
plt.show()

# %% [markdown]
# ![image.png](attachment:a72bdc76-238d-4424-a778-23744327772c.png)

# %% [markdown]
# # Challenge 4
#
# 1. You worked with two modern libraries to map big data. Can you describe the differences between working with Longboard and Datashader? Which one provides the most exciting functionality, and how do the outcomes from both of them vary?
# 2. Find a large dataset with at least 5 million records. Consider open datasets, government datasets, or any dataset of interest to you. Ensure the dataset is in a format that can be easily loaded into a Pandas DataFrame (Parquet file or another format).
# 3. Define a potential problem or scenario for mapping this dataset.
# 4. Load the dataset into a Pandas DataFrame and explore its structure. Here, **I advice you! to take a small portion of that rather than work with the entire table.**
# 5. Identify key variables of interest that could be effectively visualized using Datashader(https://datashader.org/index.html#). (e.g. is fine if the datasets have only locations, but we are aiming for at least one additional variable to represent in the map.
# 6. Use the previous steps and the Datashader documentation to implement a `hvplot` Map.
# 7. Discuss/Write any challenges you have encountered related to the challenges and how you addressed them.
# 8. As always. Provide clear comments and/or citations in your code, explaining each step of the Datashader implementation (**Note: You don't need to run the Datashader pipeline**)
#
# 9. **For next week**, create a **four-slide presentation** summarizing the problem, data source, dataset, challenges, map, and insights from visualizing the large dataset. **Two slides for Challenge 2** and the **other two for this challenge**. You can also use the Notebooks as a tool to make your presentation.

# %%
# OSError: Could not find/load shared object file
# import holoviews as hv, pandas as pd, colorcet as cc
# from holoviews.element.tiles import EsriImagery
# from holoviews.operation.datashader import datashade
# hv.extension('bokeh')
# I understand that the role of these libraries, like 'holoviews' is to provide a high-level 
# data visualization library that is extended to Bokeh and Matplotlib. Colorcet will allow the 
# installation of colormaps, while Esri images allows for esri imagery to be loaded and datashade 
# from holoviews operizes to rasterize data and display large datasets (which are the time of sets this fragment of the addigment looks at..

# %%
import holoviews as hv, pandas as pd, colorcet as cc
from holoviews.element.tiles import EsriImagery
from holoviews.operation.datashader import datashade
hv.extension('bokeh')

# %%
import hvplot.pandas

# %%
# Equally to the previous cells, OSError: Could not find/load shared object file: libllvmlite.dylib, 
# does not allow me to load the libraries below. Datashader rasterizes and visualizes large datasets, 
# trans_functions is the library that will allow for rasterized data to be turned into visual representations,
# similarly to holoviews.operation.datashader.

# %%
#Importing the required libraries.
# OSError: Could not find/load shared object file: libllvmlite.dylib. 
# import datashader as ds
# import datashader.transfer_functions as tf
# from holoviews.operation.datashader import rasterize

# %% [markdown]
# # Lab Workbook No 4: Geovisualization II - Apps.

# %% [markdown]
# ## Challenge 2
#
# 1. Go to this link https://learn.arcgis.com/en/projects/map-and-analyze-the-urban-heat-island-effect/ and follow all the instructions provided. The ETA for this tutorial is 40 mins, but I guess it will take you around 1 hrs if you are not familiar with ArcGIS Online.
#
# >In order to continue with this tutorial, you may require certain credits (the AGOL currency) and software extensions which might not be available in the University Portal. Nevertheless, they contain all the necessary data essential for completing the exercise. Therefore, it is recommended that you go through all the instructions carefully before processing any data.
#
# 2. After completing the tutorial, please take a screenshot of your final dashboard and include it in the next markdown cell along with the dashboard link.

# %% [markdown]
# ![image.png](attachment:5646305b-5518-47ae-930c-802c689f4fd5.png)

# %% [markdown]
# Link to dashboard: https://www.arcgis.com/apps/dashboards/fb695542fded436a93cd512d9b4251a7

# %% [markdown]
# ## Challenge 3
#
# Now is the time for you to create some choropleth maps.
#
# 1. Go to this portal https://www.spatialdata.gov.scot/geonetwork/srv/eng/catalog.search#/home
# 2. Get the Scottish Index of Multiple Deprivation (SIMD) 2020 dataset and extract the data only for the city of Edinburgh.
# 3. Create two static choropleth maps (e.g. `matplotlib`). These maps should represent an attribute you find interesting in the SIMD dataset. Using two different classifier methods, you need to show how the maps appear different even though the data and attributes are the same. Include a clear description of your choice and the difference in the classification method for the attribute chosen (e.g. Plotting histograms with breakpoints(bins). You can find a complete list of classifiers at https://pysal.org/mapclassify/api.html.
# 4. Finally, create other two interactive maps (e.g. `choropleth_mapbox`) - one for Glasgow and one for Edinburgh - to represent the difference in deprivation for both cities. Pick any of the available attributes.
#    > As always include the appropriate descriptions and code comments where you narrate how you are processing the data. And the insights you get from the results.

# %%
# Given the technical difficulties and me being unable to import the following libraries; 
# import plotly.express as px, import mapclassify as mc, 
# I cannot use any of the classify methods applied by the library and was therefore unable to 
# perform any of the exercises, and therefore challenge 3, of this section of the lab.

# %% [markdown]
# ## **End of Assignment 1** - 200017209
# ### GG4257 - Urban Analytics: A Toolkit for Sustainable Urban Development
